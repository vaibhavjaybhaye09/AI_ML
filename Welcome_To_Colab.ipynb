# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavjaybhaye09/AI_ML/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Student Example

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.style.use('seaborn-v0_8')
plt.rcParams['figure.figsize'] =(12,6)
plt.rcParams['figure.dpi'] = 100

# %%
np.random.seed(42)

# %%
np_students = 1000

# %%
df = pd.DataFrame({
    'students_id':range(1, np_students + 1),
    'age':np.random.randint(15,23,np_students),
    'gender': np.random.choice(['Male','Female'],np_students),
    'study_time':np.clip(np.random.normal(10,4,np_students),0,30),
    'attendance':np.clip(np.random.normal(85,15,np_students),0,100),
    'internet_access':np.random.choice(['YES','NO'],np_students),
    'parent_education':np.random.choice(['High School', 'some college','Bachelor','Master','PhD'],
                                      np_students,
                                      p = [0.2,0.25,0.3,0.2,0.05]),
    'family_support': np.random.choice(['YES','NO'],np_students,
                                       p = [0.70,0.30]),
    'extracurricular_activities': np.random.choice(['YES','NO'],
                                                   np_students,
                                                   p = [0.70,0.30]),
    'math_score': np.clip(np.random.normal(70,15,np_students)+
                         np.random.choice([0,5,10],np_students, p =[0.3,0.5,0.2]),0,100),
     'reading_score':np.clip(
        np.random.normal(72,14,np_students) +
        np.random.choice([0,5,10],np_students, p=[0.3,0.5,0.2]),
        0,100
                           ),
    'writing_score':np.clip(
        np.random.normal(71,15,np_students) +
        np.random.choice([0,5,10],np_students,p=[0.3,0.5,0.2]),
        0,100
    )


})

# %%
display(df.describe)
# Out:
# <bound method NDFrame.describe of      students_id  age  gender  study_time  attendance internet_access  \
# 0              1   21  Female   10.710804   63.905238              NO
# 1              2   18    Male    4.658623   83.753416             YES
# 2              3   19    Male   11.520791   62.429194              NO
# 3              4   21    Male   12.442343   96.400839             YES
# 4              5   17    Male   12.239162   86.236596              NO
# ..           ...  ...     ...         ...         ...             ...
# 995          996   19    Male    4.719910   80.726868             YES
# 996          997   15  Female    7.552924   81.157304              NO
# 997          998   18    Male    9.851853   81.377538             YES
# 998          999   22    Male    8.282791   84.073537             YES
# 999         1000   17    Male    7.230316   92.191623              NO
#
#     parent_education family_support extracurricular_activities  math_score  \
# ...

# %%
display(df.describe())
# Out:
#        students_id        age   study_time   attendance   math_score  \
# count  1000.000000  1000.0000  1000.000000  1000.000000  1000.000000
# mean    500.500000    18.4980    10.403130    84.061053    73.693343
# std     288.819436     2.3081     3.934506    12.681246    14.881491
# min       1.000000    15.0000     0.000000    39.707318    26.507292
# 25%     250.750000    16.7500     7.743517    75.359920    63.936174
# 50%     500.500000    18.0000    10.336856    85.160022    74.012097
# 75%     750.250000    21.0000    12.958527    94.990320    84.422714
# max    1000.000000    22.0000    22.772430   100.000000   100.000000
#
#        reading_score  writing_score
# count    1000.000000    1000.000000
# mean       76.393387      74.618257
# std        14.081794      14.382459
# min        18.286822      12.163996
# 25%        67.041499      64.589231
# 50%        77.036177      74.851717
# 75%        86.812990      84.762932
# max       100.000000     100.000000

# %%
df['average_score'] = df[['math_score','reading_score','writing_score']].mean(axis=1)
df['average_score']
# Out:
# 0      65.564243
# 1      80.370476
# 2      88.317481
# 3      81.290327
# 4      88.013664
#          ...
# 995    78.788944
# 996    66.548049
# 997    69.514995
# 998    69.654584
# 999    73.305997
# Name: average_score, Length: 1000, dtype: float64

# %%
df
# Out:
#      students_id  age  gender  study_time  attendance internet_access  \
# 0              1   21  Female   10.710804   63.905238              NO
# 1              2   18    Male    4.658623   83.753416             YES
# 2              3   19    Male   11.520791   62.429194              NO
# 3              4   21    Male   12.442343   96.400839             YES
# 4              5   17    Male   12.239162   86.236596              NO
# ..           ...  ...     ...         ...         ...             ...
# 995          996   19    Male    4.719910   80.726868             YES
# 996          997   15  Female    7.552924   81.157304              NO
# 997          998   18    Male    9.851853   81.377538             YES
# 998          999   22    Male    8.282791   84.073537             YES
# 999         1000   17    Male    7.230316   92.191623              NO
#
#     parent_education family_support extracurricular_activities  math_score  \
# ...

# %%
df['average_score'] = df['average_score'].round(2)

# %%
print(f'dataset shape {df.shape[0]} students,{df.shape[1]} features')
# Out:
# dataset shape 1000 students,13 features

# %%
df.head()
# Out:
#    students_id  age  gender  study_time  attendance internet_access  \
# 0            1   21  Female   10.710804   63.905238              NO
# 1            2   18    Male    4.658623   83.753416             YES
# 2            3   19    Male   11.520791   62.429194              NO
# 3            4   21    Male   12.442343   96.400839             YES
# 4            5   17    Male   12.239162   86.236596              NO
#
#   parent_education family_support extracurricular_activities  math_score  \
# 0         Bachelor            YES                        YES   51.513531
# 1     some college            YES                        YES   84.286930
# 2      High School            YES                         NO   95.337834
# 3              PhD            YES                        YES  100.000000
# 4      High School            YES                        YES   93.359231
#
#    reading_score  writing_score  average_score
# 0      68.605040      76.574157          65.56
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   students_id                 1000 non-null   int64
#  1   age                         1000 non-null   int64
#  2   gender                      1000 non-null   object
#  3   study_time                  1000 non-null   float64
#  4   attendance                  1000 non-null   float64
#  5   internet_access             1000 non-null   object
#  6   parent_education            1000 non-null   object
#  7   family_support              1000 non-null   object
#  8   extracurricular_activities  1000 non-null   object
#  9   math_score                  1000 non-null   float64
#  10  reading_score               1000 non-null   float64
#  11  writing_score               1000 non-null   float64
#  12  average_score               1000 non-null   float64
# ...

# %%
fig , ax = plt.subplots(figsize=(10,6))
ax.hist(df['average_score'],bins=20,color='steelblue',edgecolor='black', )
ax.axvline(df['average_score'].mean(),color='red',linestyle='dashed',linewidth=2)
ax.axvline(df['average_score'].median(),color='g',linestyle='dotted',linewidth=2)
ax.set_xlabel('Average Score')
ax.set_ylabel('number of students (Frequency)')
ax.set_title('Distribution of Average Scores')
ax.grid(True,)

# %%
numerical_col = ['age','study_time','attendance','math_score','reading_score','writing_score','average_score']

# %%
correlation_matrix = df[numerical_col].corr()

# %%
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',linewidths=0.5,
            cbar=False,fmt='.2f')
plt.title('Correlation Heatmap')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(df['study_time'],df['average_score'],
                     s=50,
                     alpha=0.6,
                     c=df['attendance'],
                     cmap='viridis',
                     edgecolor='black',
                     linewidth=0.5)
cbar = plt.colorbar(scatter,ax = ax)
cbar.set_label('Avarage Attendance')
ax.set_xlabel('Study Time')
ax.set_ylabel('Average Score')
plt.show()

# %%
fig,  ax = plt.subplots(figsize=(10,6))
sns.boxplot(data=df,x='parent_education',y='average_score',ax=ax,
            palette='Set2')
ax.set_xlabel('Parent Education')
ax.set_ylabel('Average Score')
ax.set_title('Average Score by Parent Education')
plt.xticks(rotation=45)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.boxplot(data = df,x='gender',y='average_score',ax=ax)

ax.set
# Out:
# <bound method Axes.set of <Axes: xlabel='gender', ylabel='average_score'>>

# %% [markdown]
# done my side og pd
